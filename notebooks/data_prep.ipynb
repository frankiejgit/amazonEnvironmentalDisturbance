# %%
import os
import string
import unidecode
import random

import pandas as pd
import geopandas as gpd
import plotly.express as px

import warnings
from IPython.core.interactiveshell import InteractiveShell

# %%
# Notebook configurations
warnings.filterwarnings('ignore')
pd.set_option('display.max.columns', None)
InteractiveShell.ast_node_interactivity = 'all'

# %%
# Functions 

def generate_random_id(length, id_col):
    characters = string.ascii_letters.lower() + string.digits 
    original_id = False

    while original_id is False:
        new_id = ''.join(random.choice(characters) for _ in range(length))
        if new_id not in id_col:
            original_id = True
            break
    
    return new_id

# Format string data to follow a uniform format
def normalize_text_list(text_list: list, to_replace: str = "", replace_with: str = "", remove: list or str = ""):
    return list(
        map(
            lambda x: unidecode.unidecode(str(x).translate(str(x).maketrans(to_replace, replace_with, remove))).lower().strip().strip("_"), text_list
        )
    )

# Save dataframe as a CSV
def save_df_as_csv(df, file_path):
    try:
        os.makedirs(file_path.rsplit("/", 1)[0], exist_ok=True)
        df.to_csv(file_path, index=False)
    except:
        raise

# %% [markdown]
# ## I. Convert source files to Pandas DataFrames

# %%
# Load the original source files
# Source: Inter-American Dialogue

project_path = "../data/source/consolidated_amazon_projects_data.xlsx"
project_coords = "../data/source/project_coordinates_amazon_energy_and_mining.xlsx"

# %%
mining_df = pd.read_excel(project_path, sheet_name="Mining")
oil_df = pd.read_excel(project_path, sheet_name="Oil & Gas")
hydro_df = pd.read_excel(project_path, sheet_name="Hydropower")

# %%
# Get the column names (headers) as sets for each DataFrame
hydro_columns = set(hydro_df.columns)
mining_columns = set(mining_df.columns)
oil_columns = set(oil_df.columns)

# Find the differences between the column sets
different_columns = {
    'hydro': hydro_columns - (mining_columns | oil_columns),
    'mining': mining_columns - (hydro_columns | oil_columns),
    'oil': oil_columns - (hydro_columns | mining_columns)
}

# Display the different column names for each DataFrame
for df_name, diff_columns in different_columns.items():
    if diff_columns:
        print(f"Different columns in {df_name}_df: {diff_columns}")
    else:
        print(f"No different columns in {df_name}_df")
# Out:
# Different columns in hydro_df: {'Installed Capacity (MW)'}
# Different columns in mining_df: {'Substance(s)', 'Deal Type'}
# No different columns in oil_df

# %% [markdown]
# __Note:__ Important to take into consideration the columns that are unique to each product type.

# %%
# Concatenate the DataFrames into a single DataFrame
df = pd.concat([hydro_df, oil_df, mining_df], ignore_index=True)

# %% [markdown]
# ## II. Clean and correct mismatched data

# %% [markdown]
# ### a. Format columns

# %%
# Normalize column headers 
df.columns = normalize_text_list(df.columns.values, " ", "_", ''.join([s for s in string.punctuation if s != "_"]))

# Normalize all text data
norm_cols = [col for (col, dtype) in df.dtypes.items() if dtype == "object"]

# %%
# Fix issue with duplicate 'deal_type' columns

df['deal_structure'] = df['deal_type'].iloc[:, 0] 
df['deal_mining'] = df['deal_type'].iloc[:, 1]

df = df.drop(columns=['deal_type'])
df.head()
# Out:
#   project_name sector_type  country  installed_capacity_mw  \
# 0     Ambrosia  Hydropower  Bolivia                   84.9
# 1   Banda Azul  Hydropower  Bolivia                  146.0
# 2     Chojlla   Hydropower  Bolivia                   37.0
# 3       Corani  Hydropower  Bolivia                   54.0
# 4      Ivirizu  Hydropower  Bolivia                  279.8
#
#    operational_status                     owner  equity_stake_owner  \
# 0         Permitting   Empresa Eléctrica Corani                 1.0
# 1         Permitting   Empresa Eléctrica Corani                 1.0
# 2        In Operation  Hidroeléctrica Boliviana                 1.0
# 3        In Operation  Empresa Eléctrica Corani                 1.0
# 4  Under Construction       Ende Valle Hermoso                  1.0
#
#    equity_stake_operator country_of_company_hq         company_type  \
# 0                    1.0               Bolivia                  SOE
# 1                    1.0               Bolivia                  SOE
# 2                    1.0               Bolivia  Local Power Company
# 3                    1.0               Bolivia                  SOE
# 4                    0.0               Bolivia                  SOE
#
#    company_type_for_label is_operator                    lender_type  \
# 0  State-owned Enterprise         Yes  Multilateral Development Bank
# 1  State-owned Enterprise         Yes  Foreign Development Bank/Fund
# 2     Local Power Company         Yes                            NaN
# 3  State-owned Enterprise         Yes  Multilateral Development Bank
# 4  State-owned Enterprise          No                            NaN
#
#   substances deal_structure deal_mining
# 0        NaN     Greenfield         NaN
# 1        NaN     Greenfield         NaN
# 2        NaN     Greenfield         NaN
# 3        NaN     Greenfield         NaN
# 4        NaN     Greenfield         NaN

# %%
# Create a new column 'deal_difference' to indicate differences
df['deal_difference'] = df['deal_structure'] != df['deal_mining']

# Show which sectors have differences
set(df[df['deal_difference'] == True]['sector_type'])
# Out:
# {'Hydropower', 'Mining', 'Oil & Gas'}

# %%
# Create a mask for rows where 'sector_type' equals 'mining'
mining_mask = df['sector_type'] == 'Mining'

# Use the mask to update the 'deal_structure' column
df.loc[mining_mask, 'deal_structure'] = df.loc[mining_mask, 'deal_mining']

df.tail()
# Out:
#      project_name sector_type  country  installed_capacity_mw  \
# 549      Vermelho      Mining   Brazil                    NaN
# 550    Veta Islay      Mining     Peru                    NaN
# 551  Volta Grande      Mining   Brazil                    NaN
# 552      Warintza      Mining  Ecuador                    NaN
# 553        Wynamu      Mining   Guyana                    NaN
#
#     operational_status                   owner  equity_stake_owner  \
# 549                NaN      Horizonte Minerals                 1.0
# 550                NaN  Compañía Minera Volcan                 1.0
# 551                NaN         Belo Sun Mining                 1.0
# 552                NaN       Solaris Resources                 1.0
# 553                NaN       Guyana Goldfields                 1.0
#
#      equity_stake_operator country_of_company_hq                company_type  \
# 549                    1.0                    UK          Junior Exploration
# 550                    1.0                  Peru          Junior Exploration
# 551                    1.0                Canada  Small to Mid-tier Producer
# 552                    1.0                Canada          Junior Exploration
# 553                    1.0                 China                         SOE
#
#          company_type_for_label is_operator  \
# 549          Junior Exploration         Yes
# 550          Junior Exploration         Yes
# 551  Small to Mid-tier Producer         Yes
# 552          Junior Exploration         Yes
# 553      State-owned Enterprise         Yes
#
#                                            lender_type  \
# 549                                                NaN
# 550                                                NaN
# 551  Investment Bank, Commercial Bank, Holding Comp...
# 552                                                NaN
# 553                                                NaN
#
#                      substances          deal_structure  \
# 549              Cobalt, Nickel  Full Asset Transaction
# 550  Copper, Lead, Silver, Zinc              Greenfield
# 551                        Gold              Greenfield
# 552          Copper, Molybdenum      Merger/Acquisition
# 553                        Gold              Greenfield
#
#                 deal_mining  deal_difference
# 549  Full Asset Transaction             True
# 550              Greenfield             True
# 551              Greenfield             True
# 552      Merger/Acquisition             True
# 553              Greenfield             True

# %%
# Drop the duplicate column and change name of deal_structure back to deal_type
df = df.drop(columns=["deal_mining","deal_difference"])
df.rename(columns={"deal_structure":"deal_type"}, inplace=True)

df.tail()
# Out:
#      project_name sector_type  country  installed_capacity_mw  \
# 549      Vermelho      Mining   Brazil                    NaN
# 550    Veta Islay      Mining     Peru                    NaN
# 551  Volta Grande      Mining   Brazil                    NaN
# 552      Warintza      Mining  Ecuador                    NaN
# 553        Wynamu      Mining   Guyana                    NaN
#
#     operational_status                   owner  equity_stake_owner  \
# 549                NaN      Horizonte Minerals                 1.0
# 550                NaN  Compañía Minera Volcan                 1.0
# 551                NaN         Belo Sun Mining                 1.0
# 552                NaN       Solaris Resources                 1.0
# 553                NaN       Guyana Goldfields                 1.0
#
#      equity_stake_operator country_of_company_hq                company_type  \
# 549                    1.0                    UK          Junior Exploration
# 550                    1.0                  Peru          Junior Exploration
# 551                    1.0                Canada  Small to Mid-tier Producer
# 552                    1.0                Canada          Junior Exploration
# 553                    1.0                 China                         SOE
#
#          company_type_for_label is_operator  \
# 549          Junior Exploration         Yes
# 550          Junior Exploration         Yes
# 551  Small to Mid-tier Producer         Yes
# 552          Junior Exploration         Yes
# 553      State-owned Enterprise         Yes
#
#                                            lender_type  \
# 549                                                NaN
# 550                                                NaN
# 551  Investment Bank, Commercial Bank, Holding Comp...
# 552                                                NaN
# 553                                                NaN
#
#                      substances               deal_type
# 549              Cobalt, Nickel  Full Asset Transaction
# 550  Copper, Lead, Silver, Zinc              Greenfield
# 551                        Gold              Greenfield
# 552          Copper, Molybdenum      Merger/Acquisition
# 553                        Gold              Greenfield

# %%
# Normalize text data in dataframe
for col in norm_cols:
    df[col] = normalize_text_list(df[col], " ", "_", ''.join([s for s in string.punctuation if s != "_"]))

df.head()
# Out:
#   project_name sector_type  country  installed_capacity_mw  \
# 0     ambrosia  hydropower  bolivia                   84.9
# 1   banda_azul  hydropower  bolivia                  146.0
# 2      chojlla  hydropower  bolivia                   37.0
# 3       corani  hydropower  bolivia                   54.0
# 4      ivirizu  hydropower  bolivia                  279.8
#
#    operational_status                     owner  equity_stake_owner  \
# 0          permitting  empresa_electrica_corani                 1.0
# 1          permitting  empresa_electrica_corani                 1.0
# 2        in_operation  hidroelectrica_boliviana                 1.0
# 3        in_operation  empresa_electrica_corani                 1.0
# 4  under_construction        ende_valle_hermoso                 1.0
#
#    equity_stake_operator country_of_company_hq         company_type  \
# 0                    1.0               bolivia                  soe
# 1                    1.0               bolivia                  soe
# 2                    1.0               bolivia  local_power_company
# 3                    1.0               bolivia                  soe
# 4                    0.0               bolivia                  soe
#
#   company_type_for_label is_operator                    lender_type  \
# 0  stateowned_enterprise         yes  multilateral_development_bank
# 1  stateowned_enterprise         yes   foreign_development_bankfund
# 2    local_power_company         yes                            nan
# 3  stateowned_enterprise         yes  multilateral_development_bank
# 4  stateowned_enterprise          no                            nan
#
#   substances   deal_type
# 0        nan  greenfield
# 1        nan  greenfield
# 2        nan  greenfield
# 3        nan  greenfield
# 4        nan  greenfield

# %%
print(df.info(verbose=True, show_counts=True))
print("===========Null Values=============="*3)
print(df.isna().sum())
print("============Unique Values============="*3)
print(df.nunique())
print("========================="*3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   project_name            554 non-null    object
#  1   sector_type             554 non-null    object
#  2   country                 554 non-null    object
#  3   installed_capacity_mw   100 non-null    float64
#  4   operational_status      554 non-null    object
#  5   owner                   554 non-null    object
#  6   equity_stake_owner      554 non-null    float64
#  7   equity_stake_operator   554 non-null    float64
#  8   country_of_company_hq   554 non-null    object
#  9   company_type            554 non-null    object
#  10  company_type_for_label  554 non-null    object
#  11  is_operator             554 non-null    object
#  12  lender_type             554 non-null    object
#  13  substances              554 non-null    object
#  14  deal_type               554 non-null    object
# dtypes: float64(3), object(12)
# memory usage: 65.0+ KB
# None
# ===========Null Values=========================Null Values=========================Null Values==============
# project_name                0
# sector_type                 0
# country                     0
# installed_capacity_mw     454
# operational_status          0
# owner                       0
# equity_stake_owner          0
# equity_stake_operator       0
# country_of_company_hq       0
# company_type                0
# company_type_for_label      0
# is_operator                 0
# lender_type                 0
# substances                  0
# deal_type                   0
# dtype: int64
# ============Unique Values=========================Unique Values=========================Unique Values=============
# project_name              416
# sector_type                 3
# country                     9
# installed_capacity_mw      67
# operational_status          7
# owner                     278
# equity_stake_owner         47
# equity_stake_operator      30
# country_of_company_hq      35
# company_type               11
# company_type_for_label     11
# is_operator                 3
# lender_type                31
# substances                 32
# deal_type                   4
# dtype: int64
# ===========================================================================

# %% [markdown]
# ### b. Correct company names
#
# This had to be a manual effort, checking each company and doing some research online to identify which companies operate under different names or use multiple subsidiaries.

# %%
sorted(df.owner.value_counts().items(), key=lambda x: x[0])
# Out:
# [('aguaytia_energy_del_peru', 1),
#  ('alcoa_corporation', 1),
#  ('alicanto_minerals', 1),
#  ('alta_floresta_gold_mineracao', 1),
#  ('altamira_gold', 2),
#  ('alupar_investimento', 1),
#  ('amazonas_geracao_e_transmissao_de_energia', 1),
#  ('amazonia_energia_sa', 1),
#  ('amerisur_exploracion_colombia', 5),
#  ('amerisur_resources', 4),
#  ('amodaimi_oil_co', 1),
#  ('andes_petroleum_ecuador', 3),
#  ('anglo_american', 1),
#  ('apoio_engenharia_e_mineracao', 1),
#  ('ariana_operaciones_mineras', 1),
#  ('arrow_exploration_corp', 1),
#  ('auplata_mining_group', 1),
#  ('aura_minerals', 2),
#  ('aurania_resources', 1),
#  ('avanco_resources', 2),
#  ('avb_mineracao', 1),
#  ('barrick_gold', 1),
#  ('bbx_minerals', 1),
#  ('belo_sun_mining', 1),
#  ('bhp_group', 1),
#  ('boa_vista_gold', 1),
#  ('brazauro_recursos_minerais', 1),
#  ('cabral_gold', 1),
#  ('caixa_fundo_de_investimentos_em_participacoes_amazonia_energia', 1),
#  ('campo_puma_oriente', 1),
#  ('canacol_energy', 1),
#  ('canacol_energy_colombia', 1),
#  ('canadian_energy_enterprises_cee_srl', 1),
#  ('capstone_mining', 1),
#  ('cementos_selva', 2),
#  ('cemig_geracao_e_transmissao', 1),
#  ('centaurus_metals', 3),
#  ('centrais_eletricas_brasileiras_eletrobras', 1),
#  ('centrais_eletricas_do_norte_do_brasil_eletrobas_eletronorte', 5),
#  ('central_hidroelectrica_huallaga_hydro', 1),
#  ('centromin_peru', 1),
#  ('cepsa_colombia', 2),
#  ('cerro_del_aguila_sa', 1),
#  ('china_gezhouba_group', 1),
#  ('china_national_petroleum_corporation_cnpc', 2),
#  ('china_three_gorges_corporation', 4),
#  ('chinango_sac', 2),
#  ('cinco_estrelas_agropecuaria_e_participacoes', 1),
#  ('citic_metal_co_ltd', 1),
#  ('codelco_do_brasil_mineracao', 1),
#  ('colossus_minerals', 1),
#  ('columbus_energy_resources', 1),
#  ('compagnie_miniere_esperance', 1),
#  ('companhia_brasileira_de_aluminio', 1),
#  ('companhia_hidreletrica_do_sao_francisco', 2),
#  ('companhia_hidroeletrica_do_sao_francisco', 1),
#  ('companhia_paranaense_de_energia_sa', 1),
#  ('compania_boliviana_de_energia_electrica', 1),
#  ('compania_energetica_veracruz', 1),
#  ('compania_espanola_de_petroleos_cespa', 1),
#  ('compania_minera_volcan', 1),
#  ('compania_sudamericana_de_fosforos_del_ecuador_fosforocomp', 2),
#  ('cooperativa_de_garimpeiros_de_santa_cruz', 1),
#  ('cooperativa_de_mineracao_dos_garimpeiros_de_serra_pelada', 1),
#  ('cooperativa_metalurgica_de_rondonia_ltda', 1),
#  ('corporacion_electrica_del_ecuador_celec_ep', 3),
#  ('corporacion_venezolana_de_guayana_cvg', 1),
#  ('corporacion_venezolana_de_guayana_minerven', 1),
#  ('corporacion_venezolana_de_mineria_cvm', 1),
#  ('corporacion_venezolana_del_petroleo_cvp', 3),
#  ('cosigo_resources', 1),
#  ('crs_resources_ecuador', 1),
#  ('cruz_del_sol', 2),
#  ('ct_energy_holding', 1),
#  ('decker_petroleum_marketing', 1),
#  ('dong_won_corporation', 1),
#  ('ecuacorriente', 1),
#  ('ecuaenergia', 1),
#  ('edf_norte_fluminense', 1),
#  ('edp_brasil', 3),
#  ('egejunin_tulumayo_v_sac', 1),
#  ('electrificacion_del_caroni', 3),
#  ('eletrogoes_sa', 1),
#  ('eletrosul_centrais_eletricas_eletrosul', 2),
#  ('elienergy', 1),
#  ('emerald_energy', 5),
#  ('empresa_colombiana_de_petroleos_ecopetrol', 14),
#  ('empresa_de_generacion_electrica_ccollpani', 1),
#  ('empresa_de_generacion_electrica_machupicchu', 1),
#  ('empresa_de_generacion_electrica_san_gaban', 1),
#  ('empresa_electrica_corani', 7),
#  ('empresa_electrica_regional_del_sur', 1),
#  ('empresa_electricidad_del_peru_electroperu', 2),
#  ('empresa_estatal_unitaria_union_de_empresas_productoras_belorusneft', 1),
#  ('empresa_nacional_de_electricidad_ende', 1),
#  ('enap_sipetrol', 2),
#  ('ende_valle_hermoso', 1),
#  ('enel_generacion_piura', 1),
#  ('enel_green_power_brasil_participacoes', 1),
#  ('energia_azul', 1),
#  ('energoret_sac', 1),
#  ('eneva', 5),
#  ('engie', 1),
#  ('engie_energia_peru', 1),
#  ('eni_lasmo_plc', 1),
#  ('entidades_de_previdencia_complementar', 1),
#  ('eop_operaciones_petroleras', 1),
#  ('equinox_gold', 1),
#  ('equion_energia', 1),
#  ('explorcobres', 1),
#  ('falcao_mineradora', 1),
#  ('first_bauxite', 1),
#  ('frontera_energy', 4),
#  ('frontera_energy_colombia', 4),
#  ('furnas_centrais_eletricas_eletrobras_furnas', 3),
#  ('g2_goldfields', 1),
#  ('gazprom', 1),
#  ('generadora_de_energia_del_peru', 1),
#  ('gente_oil_ecuador_pte_ltd', 1),
#  ('geopark', 6),
#  ('geopark_colombia', 2),
#  ('geopark_peru', 1),
#  ('gold_reserve', 1),
#  ('gold_x_mining_corp', 1),
#  ('goldmining', 5),
#  ('goldsource_mines', 1),
#  ('gran_tierra_energy', 5),
#  ('gran_tierra_energy_colombia', 16),
#  ('great_panther_mining_limited', 1),
#  ('greenpower_energy_limited', 1),
#  ('guoxin_international_investment_co', 1),
#  ('guyana_goldfields', 2),
#  ('guyana_strategic_metals', 1),
#  ('hannan_metals', 1),
#  ('harvest_gold', 1),
#  ('hidroabanico', 1),
#  ('hidroelectrica_boliviana', 2),
#  ('hidrosanbartolo_sa', 1),
#  ('hocol_sa', 3),
#  ('horizonte_minerals', 3),
#  ('hunt_oil_company_of_peru', 2),
#  ('hupecol_operating_co', 1),
#  ('hydro_global_peru_ctg_and_edp', 2),
#  ('iamgold', 3),
#  ('instituto_de_seguridad_social_de_las_fuerzas_armadas', 1),
#  ('itamarati_norte', 1),
#  ('jmalucelli_energia', 1),
#  ('joshi_technologies_international', 1),
#  ('kilroy_mining', 2),
#  ('korea_electric_power_corp', 1),
#  ('korea_national_oil_corporation', 1),
#  ('lara_exploration', 4),
#  ('lewis_energy_colombia', 1),
#  ('libero_copper', 1),
#  ('lucky_minerals', 1),
#  ('luminex_resources', 3),
#  ('lundin_gold', 1),
#  ('luz_del_sur', 1),
#  ('macusani_yellowcake', 1),
#  ('matpetrol', 1),
#  ('meridian_mineracao_jaburi', 2),
#  ('meridian_mining', 1),
#  ('meteoric_resources', 1),
#  ('minera_irl', 1),
#  ('mineracao_aurizona', 1),
#  ('mineracao_dardanelos', 1),
#  ('mineracao_do_para', 1),
#  ('mineracao_iraja_sa', 1),
#  ('mineracao_santa_elina_industria_e_comercio', 1),
#  ('minsur', 1),
#  ('mitsui__co', 1),
#  ('mmg_limited', 1),
#  ('mompos_oil_company_inc', 1),
#  ('neoenergia', 3),
#  ('newmont_corporation', 3),
#  ('nordgold', 1),
#  ('normantrust_group', 1),
#  ('norsk_hydro', 2),
#  ('nueva_esperanza_hydro', 1),
#  ('occidental_andina_llc', 1),
#  ('occidental_petroleum_corporation', 1),
#  ('odebrecht', 1),
#  ('odebrecht_energia_do_brasil', 1),
#  ('odebrecht_energia_sa', 1),
#  ('on_energy_inc', 1),
#  ('orea_mining', 3),
#  ('origen_group', 1),
#  ('orion_energy_ocanopb', 1),
#  ('orionoil_er_sa', 1),
#  ('ouro_preto_oleo_e_gas', 1),
#  ('overseas_petroleum_and_investment_corporation', 2),
#  ('palamina', 2),
#  ('parnaiba_gas_natural', 1),
#  ('pdvsa', 1),
#  ('perenco', 1),
#  ('perenco_peru_petroleum', 1),
#  ('perenco_venezuela_petroleo_y_gas', 1),
#  ('peruana_de_energia', 1),
#  ('petro_caribbean_resources', 1),
#  ('petroamazonas_ep', 21),
#  ('petrobell_incgrantmining_sa', 1),
#  ('petrochina', 1),
#  ('petrogal_brasil', 1),
#  ('petroleo_brasileiro_petrobras', 10),
#  ('petroleos_del_peru_petroperu', 1),
#  ('petroleos_sudamericanos_del_ecuador_petrolamerec', 4),
#  ('petrominerales_colombia', 1),
#  ('petrooriental', 2),
#  ('petroriva', 2),
#  ('petrotal', 2),
#  ('pluspetrol', 3),
#  ('pluspetrol_bolivia_corporation', 4),
#  ('pluspetrol_ecuador', 1),
#  ('pluspetrol_resources_corp', 1),
#  ('posco_international', 1),
#  ('pvep_peru', 1),
#  ('queiroz_galvao_energetica', 1),
#  ('quimpac', 1),
#  ('reliance_exploration__production_peru', 1),
#  ('repsol', 5),
#  ('repsol_ecuador', 2),
#  ('repsol_ep_bolivia', 4),
#  ('repsol_exploracion_guyana', 1),
#  ('reunion_gold', 4),
#  ('rial_minera', 1),
#  ('rio_blanco_copper', 1),
#  ('rio_tinto', 2),
#  ('rio_tinto_minera_peru_limitada', 1),
#  ('romanex_guyana_exploration', 1),
#  ('rosneft_brasil_ep', 13),
#  ('saag_investimentos', 1),
#  ('serabi_gold', 2),
#  ('shona_energy_colombia', 1),
#  ('sinohydro_corporation', 1),
#  ('sk_innovation', 3),
#  ('societe_des_mines_de_saintelie', 1),
#  ('societe_miniere_yaoudorlin', 1),
#  ('solaris_resources', 1),
#  ('solgold', 2),
#  ('solitario_exploration', 1),
#  ('soma_gold', 1),
#  ('sonatrach_peru_corporation', 2),
#  ('south32', 1),
#  ('staatsolie_maatschappij_suriname_staatsolie', 5),
#  ('staatsolie_power_company_suriname', 1),
#  ('statkraft', 2),
#  ('steinmar', 1),
#  ('stonegate_agricom', 1),
#  ('stratagold_guyana', 1),
#  ('stronghold_guyana', 1),
#  ('suroco_energy', 1),
#  ('talisman_colombia_oil__gas', 2),
#  ('tangara_energia', 1),
#  ('tecpetrol_bloque_56', 2),
#  ('tecpetrol_colombia', 1),
#  ('tempus_resources_limited', 1),
#  ('tessarema_resources_inc', 1),
#  ('the_simulus_group', 1),
#  ('triboilgas', 1),
#  ('tristar_gold', 1),
#  ('troy_resources', 1),
#  ('u3o8_corporation', 1),
#  ('union_miniere_de_saul', 1),
#  ('universal_stream', 1),
#  ('vale', 6),
#  ('vale_e_cemig', 1),
#  ('vetra_exploracion_y_produccion', 2),
#  ('vintage_petroleum_boliviana', 1),
#  ('votorantim_metais', 1),
#  ('wbd_gold', 1),
#  ('winshear_gold', 1),
#  ('ypf_bolivia', 1),
#  ('ypf_ep_peru', 2),
#  ('ypfb', 5),
#  ('ypfb_andina_repsol__ypfb', 39),
#  ('ypfb_andina_repsol__ypfb__isnt_this_bolivia_noc', 1),
#  ('ypfb_chaco', 23),
#  ('zinc_one_resources', 1)]

# %%
owner_mapping_dict = {
    'amazonia_energia': ['amazonia_energia_sa','caixa_fundo_de_investimentos_em_participacoes_amazonia_energia'],
    'goldmining':['gold_x_mining_corp'],
    'perenco': ['perenco_peru_petroleum', 'perenco_venezuela_petroleo_y_gas'],
    'orion': ['orionoil_er_sa','orion_energy_ocanopb'],
    'amerisur': ['amerisur_resources','amerisur_exploracion_colombia'],
    'gran_tierra_energy': ['gran_tierra_energy_colombia'],
    'repsol': ['repsol_ecuador','repsol_ep_bolivia','repsol_exploracion_guyana'],
    'odebrecht': ['odebrecht_energia_do_brasil','odebrecht_energia_sa'],
    'engie': ['engie_energia_peru'],
    'rio_tinto': ['rio_tinto_minera_peru_limitada'],
    'geopark': ['geopark_colombia', 'geopark_peru'],
    'staatsolie': ['staatsolie_maatschappij_suriname_staatsolie','staatsolie_power_company_suriname'],
    'eletrobras': [
        'centrais_eletricas_brasileiras_eletrobras',
        'centrais_eletricas_do_norte_do_brasil_eletrobas_eletronorte',
        'furnas_centrais_eletricas_eletrobras_furnas'
        ],
    'pluspetrol': ['pluspetrol_bolivia_corporation', 'pluspetrol_ecuador', 'pluspetrol_resources_corp'],
    'frontera_energy': ['frontera_energy_colombia'],
    'tecpetrol': ['tecpetrol_colombia','tecpetrol_bloque_56'],
    'hunt_oil_company': ['hunt_oil_company_of_peru'],
    'companhia_hidroeletrica_do_sao_francisco': ['companhia_hidreletrica_do_sao_francisco'],
    'meridian_mining': ['meridian_mineracao_jaburi'],
    'cvg': [
        'corporacion_venezolana_de_guayana_cvg',
        'corporacion_venezolana_de_guayana_minerven',
        'electrificacion_del_caroni'],
    'ypf': ['ypf_bolivia', 'ypf_ep_peru'],
    'ypfb': ['ypfb_andina_repsol__ypfb','ypfb_andina_repsol__ypfb__isnt_this_bolivia_noc','ypfb_chaco'],
    'canacol_energy': ['canacol_energy_colombia'],
    'enel': ['enel_generacion_piura','enel_green_power_brasil_participacoes'],
    'avanco_resources': ['avb_mineracao'],
    'cepsa': ['cepsa_colombia', 'compania_espanola_de_petroleos_cespa'],
    'edf': ['edf_norte_fluminense'],
    'edp': ['edp_brasil'],
    'eletrosul': ['eletrosul_centrais_eletricas_eletrosul'],
    'corporacion_fonafe': [
        'empresa_de_generacion_electrica_san_gaban',
        'empresa_de_generacion_electrica_machupicchu',
        'petroleos_del_peru_petroperu',
        'empresa_electricidad_del_peru_electroperu'
        ],
    'ende': [
        'empresa_electrica_corani',
        'empresa_nacional_de_electricidad_ende',
        'ende_valle_hermoso'],
    'crs_resources': ['crs_resources_ecuador'],
    'sonatrach': ['sonatrach_peru_corporation'],
    'talisman': ['talisman_colombia_oil_gas'],
    'vintage_petroleum': ['vintage_petroleum_boliviana'],
    'vale': ['vale_e_cemig']
}

# %%
valid_list = []

# Loop through the values in the dictionary and extend the combined_list
for val in owner_mapping_dict.values():
    valid_list.extend(val)

# %%
# Extract unique values from 'owner' column that are not in valid_list
unique_owners = df['owner'].unique()
filtered_owners = [owner for owner in unique_owners if owner not in valid_list]

# Sort the filtered owners alphabetically
filtered_owners.sort()

# Print the filtered and sorted owners
for owner in filtered_owners:
    print(owner)
# Out:
# aguaytia_energy_del_peru
# alcoa_corporation
# alicanto_minerals
# alta_floresta_gold_mineracao
# altamira_gold
# alupar_investimento
# amazonas_geracao_e_transmissao_de_energia
# amodaimi_oil_co
# andes_petroleum_ecuador
# anglo_american
# apoio_engenharia_e_mineracao
# ariana_operaciones_mineras
# arrow_exploration_corp
# auplata_mining_group
# aura_minerals
# aurania_resources
# avanco_resources
# barrick_gold
# bbx_minerals
# belo_sun_mining
# bhp_group
# boa_vista_gold
# brazauro_recursos_minerais
# cabral_gold
# campo_puma_oriente
# canacol_energy
# canadian_energy_enterprises_cee_srl
# capstone_mining
# cementos_selva
# cemig_geracao_e_transmissao
# centaurus_metals
# central_hidroelectrica_huallaga_hydro
# centromin_peru
# cerro_del_aguila_sa
# china_gezhouba_group
# china_national_petroleum_corporation_cnpc
# china_three_gorges_corporation
# chinango_sac
# cinco_estrelas_agropecuaria_e_participacoes
# citic_metal_co_ltd
# codelco_do_brasil_mineracao
# colossus_minerals
# columbus_energy_resources
# compagnie_miniere_esperance
# companhia_brasileira_de_aluminio
# companhia_hidroeletrica_do_sao_francisco
# companhia_paranaense_de_energia_sa
# compania_boliviana_de_energia_electrica
# compania_energetica_veracruz
# compania_minera_volcan
# compania_sudamericana_de_fosforos_del_ecuador_fosforocomp
# cooperativa_de_garimpeiros_de_santa_cruz
# cooperativa_de_mineracao_dos_garimpeiros_de_serra_pelada
# cooperativa_metalurgica_de_rondonia_ltda
# corporacion_electrica_del_ecuador_celec_ep
# corporacion_venezolana_de_mineria_cvm
# corporacion_venezolana_del_petroleo_cvp
# cosigo_resources
# cruz_del_sol
# ct_energy_holding
# decker_petroleum_marketing
# dong_won_corporation
# ecuacorriente
# ecuaenergia
# egejunin_tulumayo_v_sac
# eletrogoes_sa
# elienergy
# emerald_energy
# empresa_colombiana_de_petroleos_ecopetrol
# empresa_de_generacion_electrica_ccollpani
# empresa_electrica_regional_del_sur
# empresa_estatal_unitaria_union_de_empresas_productoras_belorusneft
# enap_sipetrol
# energia_azul
# energoret_sac
# eneva
# engie
# eni_lasmo_plc
# entidades_de_previdencia_complementar
# eop_operaciones_petroleras
# equinox_gold
# equion_energia
# explorcobres
# falcao_mineradora
# first_bauxite
# frontera_energy
# g2_goldfields
# gazprom
# generadora_de_energia_del_peru
# gente_oil_ecuador_pte_ltd
# geopark
# gold_reserve
# goldmining
# goldsource_mines
# gran_tierra_energy
# great_panther_mining_limited
# greenpower_energy_limited
# guoxin_international_investment_co
# guyana_goldfields
# guyana_strategic_metals
# hannan_metals
# harvest_gold
# hidroabanico
# hidroelectrica_boliviana
# hidrosanbartolo_sa
# hocol_sa
# horizonte_minerals
# hupecol_operating_co
# hydro_global_peru_ctg_and_edp
# iamgold
# instituto_de_seguridad_social_de_las_fuerzas_armadas
# itamarati_norte
# jmalucelli_energia
# joshi_technologies_international
# kilroy_mining
# korea_electric_power_corp
# korea_national_oil_corporation
# lara_exploration
# lewis_energy_colombia
# libero_copper
# lucky_minerals
# luminex_resources
# lundin_gold
# luz_del_sur
# macusani_yellowcake
# matpetrol
# meridian_mining
# meteoric_resources
# minera_irl
# mineracao_aurizona
# mineracao_dardanelos
# mineracao_do_para
# mineracao_iraja_sa
# mineracao_santa_elina_industria_e_comercio
# minsur
# mitsui__co
# mmg_limited
# mompos_oil_company_inc
# neoenergia
# newmont_corporation
# nordgold
# normantrust_group
# norsk_hydro
# nueva_esperanza_hydro
# occidental_andina_llc
# occidental_petroleum_corporation
# odebrecht
# on_energy_inc
# orea_mining
# origen_group
# ouro_preto_oleo_e_gas
# overseas_petroleum_and_investment_corporation
# palamina
# parnaiba_gas_natural
# pdvsa
# perenco
# peruana_de_energia
# petro_caribbean_resources
# petroamazonas_ep
# petrobell_incgrantmining_sa
# petrochina
# petrogal_brasil
# petroleo_brasileiro_petrobras
# petroleos_sudamericanos_del_ecuador_petrolamerec
# petrominerales_colombia
# petrooriental
# petroriva
# petrotal
# pluspetrol
# posco_international
# pvep_peru
# queiroz_galvao_energetica
# quimpac
# reliance_exploration__production_peru
# repsol
# reunion_gold
# rial_minera
# rio_blanco_copper
# rio_tinto
# romanex_guyana_exploration
# rosneft_brasil_ep
# saag_investimentos
# serabi_gold
# shona_energy_colombia
# sinohydro_corporation
# sk_innovation
# societe_des_mines_de_saintelie
# societe_miniere_yaoudorlin
# solaris_resources
# solgold
# solitario_exploration
# soma_gold
# south32
# statkraft
# steinmar
# stonegate_agricom
# stratagold_guyana
# stronghold_guyana
# suroco_energy
# talisman_colombia_oil__gas
# tangara_energia
# tempus_resources_limited
# tessarema_resources_inc
# the_simulus_group
# triboilgas
# tristar_gold
# troy_resources
# u3o8_corporation
# union_miniere_de_saul
# universal_stream
# vale
# vetra_exploracion_y_produccion
# votorantim_metais
# wbd_gold
# winshear_gold
# ypfb
# zinc_one_resources

# %% [markdown]
# ### c. Add new columns
#
# All duplicates were accounted for; two columns `parent_org` and `pid` (project ID) are created to show the hierarchy between projects and have an easier way of interacting with them.

# %%
parent_list = []

for row, data in df.iterrows():
    #print(row, data['owner'])
    if data['owner'] in owner_mapping_dict.keys():
            parent_list.append((row, data['owner']))
    elif data['owner'] in valid_list:
        for key, val in owner_mapping_dict.items():
            if data['owner'] in val:
                parent_list.append((row, key))
    else:
        parent_list.append((row, data['owner'] ))

print(parent_list)
# Out:
# [(0, 'ende'), (1, 'ende'), (2, 'hidroelectrica_boliviana'), (3, 'ende'), (4, 'ende'), (5, 'ende'), (6, 'ende'), (7, 'ende'), (8, 'ende'), (9, 'ende'), (10, 'hidroelectrica_boliviana'), (11, 'amazonas_geracao_e_transmissao_de_energia'), (12, 'odebrecht'), (13, 'amazonia_energia'), (14, 'eletrobras'), (15, 'entidades_de_previdencia_complementar'), (16, 'jmalucelli_energia'), (17, 'vale'), (18, 'companhia_paranaense_de_energia_sa'), (19, 'eletrobras'), (20, 'eletrobras'), (21, 'companhia_hidroeletrica_do_sao_francisco'), (22, 'mineracao_santa_elina_industria_e_comercio'), (23, 'cinco_estrelas_agropecuaria_e_participacoes'), (24, 'queiroz_galvao_energetica'), (25, 'companhia_hidroeletrica_do_sao_francisco'), (26, 'eletrosul'), (27, 'itamarati_norte'), (28, 'eletrobras'), (29, 'amazonia_energia'), (30, 'cemig_geracao_e_transmissao'), (31, 'eletrobras'), (32, 'odebrecht'), (33, 'saag_investimentos'), (34, 'eletrobras'), (35, 'eletrosul'), (36, 'eletrobras'), (37, 'odebrecht'), (38, 'eletrobras'), (39, 'alupar_investimento'), (40, 'eletrobras'), (41, 'companhia_hidroeletrica_do_sao_francisco'), (42, 'tangara_energia'), (43, 'china_three_gorges_corporation'), (44, 'china_three_gorges_corporation'), (45, 'sinohydro_corporation'), (46, 'hydro_global_peru_ctg_and_edp'), (47, 'china_gezhouba_group'), (48, 'luz_del_sur'), (49, 'china_three_gorges_corporation'), (50, 'china_three_gorges_corporation'), (51, 'universal_stream'), (52, 'hidroabanico'), (53, 'corporacion_electrica_del_ecuador_celec_ep'), (54, 'corporacion_electrica_del_ecuador_celec_ep'), (55, 'empresa_electrica_regional_del_sur'), (56, 'ecuaenergia'), (57, 'normantrust_group'), (58, 'corporacion_electrica_del_ecuador_celec_ep'), (59, 'elienergy'), (60, 'hidrosanbartolo_sa'), (61, 'edf'), (62, 'engie'), (63, 'engie'), (64, 'eletrogoes_sa'), (65, 'chinango_sac'), (66, 'enel'), (67, 'enel'), (68, 'compania_energetica_veracruz'), (69, 'chinango_sac'), (70, 'mitsui__co'), (71, 'statkraft'), (72, 'statkraft'), (73, 'generadora_de_energia_del_peru'), (74, 'empresa_de_generacion_electrica_ccollpani'), (75, 'cerro_del_aguila_sa'), (76, 'compania_boliviana_de_energia_electrica'), (77, 'peruana_de_energia'), (78, 'corporacion_fonafe'), (79, 'corporacion_fonafe'), (80, 'corporacion_fonafe'), (81, 'corporacion_fonafe'), (82, 'energoret_sac'), (83, 'egejunin_tulumayo_v_sac'), (84, 'centromin_peru'), (85, 'energia_azul'), (86, 'edp'), (87, 'hydro_global_peru_ctg_and_edp'), (88, 'edp'), (89, 'edp'), (90, 'korea_electric_power_corp'), (91, 'neoenergia'), (92, 'central_hidroelectrica_huallaga_hydro'), (93, 'neoenergia'), (94, 'neoenergia'), (95, 'staatsolie'), (96, 'nueva_esperanza_hydro'), (97, 'cvg'), (98, 'cvg'), (99, 'cvg'), (100, 'sonatrach'), (101, 'sonatrach'), (102, 'pluspetrol'), (103, 'pluspetrol'), (104, 'tecpetrol'), (105, 'petroriva'), (106, 'petroriva'), (107, 'pluspetrol'), (108, 'tecpetrol'), (109, 'ypf'), (110, 'ypf'), (111, 'ypf'), (112, 'tecpetrol'), (113, 'pluspetrol'), (114, 'pluspetrol'), (115, 'pluspetrol'), (116, 'pluspetrol'), (117, 'pluspetrol'), (118, 'empresa_estatal_unitaria_union_de_empresas_productoras_belorusneft'), (119, 'ypfb'), (120, 'ypfb'), (121, 'ypfb'), (122, 'ypfb'), (123, 'ypfb'), (124, 'ypfb'), (125, 'ypfb'), (126, 'ypfb'), (127, 'ypfb'), (128, 'ypfb'), (129, 'ypfb'), (130, 'ypfb'), (131, 'ypfb'), (132, 'ypfb'), (133, 'ypfb'), (134, 'ypfb'), (135, 'ypfb'), (136, 'ypfb'), (137, 'ypfb'), (138, 'ypfb'), (139, 'ypfb'), (140, 'ypfb'), (141, 'ypfb'), (142, 'ypfb'), (143, 'ypfb'), (144, 'ypfb'), (145, 'ypfb'), (146, 'ypfb'), (147, 'ypfb'), (148, 'ypfb'), (149, 'ypfb'), (150, 'ypfb'), (151, 'ypfb'), (152, 'ypfb'), (153, 'ypfb'), (154, 'ypfb'), (155, 'ypfb'), (156, 'ypfb'), (157, 'ypfb'), (158, 'ypfb'), (159, 'ypfb'), (160, 'ypfb'), (161, 'ypfb'), (162, 'ypfb'), (163, 'ypfb'), (164, 'matpetrol'), (165, 'ypfb'), (166, 'canadian_energy_enterprises_cee_srl'), (167, 'ypfb'), (168, 'ypfb'), (169, 'petroleo_brasileiro_petrobras'), (170, 'petroleo_brasileiro_petrobras') ...

# %%
# Create parent column
df['parent_org'] = [v for (k,v) in parent_list]

# Generate a column of random UUIDs
df['pid'] = [0] * len(df)
df['pid'] = [generate_random_id(6, df['pid']) for _ in range(len(df))]

df.head(10)
# Out:
#           project_name sector_type  country  installed_capacity_mw  \
# 0             ambrosia  hydropower  bolivia                   84.9
# 1           banda_azul  hydropower  bolivia                  146.0
# 2              chojlla  hydropower  bolivia                   37.0
# 3               corani  hydropower  bolivia                   54.0
# 4              ivirizu  hydropower  bolivia                  279.8
# 5             misicuni  hydropower  bolivia                  185.5
# 6            palillada  hydropower  bolivia                  118.0
# 7        san_jose_cora  hydropower  bolivia                  124.0
# 8  santa_isabel_corani  hydropower  bolivia                   93.4
# 9             umapalca  hydropower  bolivia                   85.0
#
#    operational_status                                  owner  \
# 0          permitting               empresa_electrica_corani
# 1          permitting               empresa_electrica_corani
# 2        in_operation               hidroelectrica_boliviana
# 3        in_operation               empresa_electrica_corani
# 4  under_construction                     ende_valle_hermoso
# 5        in_operation  empresa_nacional_de_electricidad_ende
# 6  under_construction               empresa_electrica_corani
# 7        in_operation               empresa_electrica_corani
# 8        in_operation               empresa_electrica_corani
# 9  under_construction               empresa_electrica_corani
#
#    equity_stake_owner  equity_stake_operator country_of_company_hq  \
# 0                 1.0                    1.0               bolivia
# 1                 1.0                    1.0               bolivia
# 2                 1.0                    1.0               bolivia
# 3                 1.0                    1.0               bolivia
# 4                 1.0                    0.0               bolivia
# 5                 0.5                    1.0               bolivia
# 6                 1.0                    1.0               bolivia
# 7                 1.0                    1.0               bolivia
# 8                 1.0                    1.0               bolivia
# 9                 1.0                    1.0               bolivia
#
#           company_type company_type_for_label is_operator  \
# 0                  soe  stateowned_enterprise         yes
# 1                  soe  stateowned_enterprise         yes
# 2  local_power_company    local_power_company         yes
# 3                  soe  stateowned_enterprise         yes
# 4                  soe  stateowned_enterprise          no
# 5                  soe  stateowned_enterprise         yes
# 6                  soe  stateowned_enterprise         yes
# 7                  soe  stateowned_enterprise         yes
# 8                  soe  stateowned_enterprise         yes
# 9                  soe  stateowned_enterprise         yes
#
#                                          lender_type substances   deal_type  \
# 0                      multilateral_development_bank        nan  greenfield
# 1                       foreign_development_bankfund        nan  greenfield
# 2                                                nan        nan  greenfield
# 3                      multilateral_development_bank        nan  greenfield
# 4                                                nan        nan  greenfield
# 5  multilateral_development_bank_multilateral_dev...        nan  greenfield
# 6                                                nan        nan  greenfield
# 7                      multilateral_development_bank        nan  greenfield
# 8                      multilateral_development_bank        nan  greenfield
# 9                                                nan        nan  greenfield
#
#                  parent_org     pid
# 0                      ende  kl0fxe
# 1                      ende  ffjpph
# 2  hidroelectrica_boliviana  1cxvzq
# 3                      ende  eh6ntx
# 4                      ende  l1dro7
# 5                      ende  pwmme6
# 6                      ende  tu1we7
# 7                      ende  oxxp9d
# 8                      ende  qm6qvg
# 9                      ende  pq754w

# %%
# Fix sectory_type value for oil and gas
df['sector_type'] = df['sector_type'].str.replace('oil__gas', 'oil_gas')

# %% [markdown]
# ## III. Geospatial Data

# %%
# Load coordinates dataset
hydro_coords = pd.read_excel(project_coords, sheet_name="Hydro")
oil_coords = pd.read_excel(project_coords, sheet_name="Oil & Gas")
mining_coords = pd.read_excel(project_coords, sheet_name="Mining")

print(hydro_df.shape, hydro_coords.shape)
print(oil_df.shape, oil_coords.shape)
print(mining_df.shape, mining_coords.shape)
# Out:
# (100, 14) (100, 3)
# (302, 12) (302, 3)
# (152, 13) (152, 3)

# %%
# Add sector_type column 
hydro_coords['sector_type'] = "hydropower"
oil_coords['sector_type'] = "oil_gas"
mining_coords['sector_type'] = "mining"

# Join the datasets
coords = pd.concat([hydro_coords, oil_coords, mining_coords], ignore_index=True)

# %%
# Normalize column headers
coords.columns = normalize_text_list(coords.columns.values, " ", "_", ''.join([s for s in string.punctuation if s != "_"]))

# Normalize values in project_name column
coords['project_name'] = normalize_text_list(coords['project_name'], " ", "_", ''.join([s for s in string.punctuation if s != "_"]))

coords.head()
# Out:
#          project_name  latitude  longitude sector_type
# 0             abanico  -2.25617  -78.19793  hydropower
# 1  afobaka_brokopondo   5.00000  -55.00000  hydropower
# 2            ambrosia -17.00910  -65.64090  hydropower
# 3      angel_i_ii_iii -13.66330  -70.53820  hydropower
# 4           anto_ruiz -13.88330  -70.20000  hydropower

# %%
# Create geometric points for each coordinate using GeoPandas
geo_coords = gpd.GeoDataFrame(coords, geometry=gpd.points_from_xy(coords['longitude'],coords['latitude']))
geo_coords.crs = {'init':'epsg:4326'}

# %%
geo_coords.head()
# Out:
#          project_name  latitude  longitude sector_type  \
# 0             abanico  -2.25617  -78.19793  hydropower
# 1  afobaka_brokopondo   5.00000  -55.00000  hydropower
# 2            ambrosia -17.00910  -65.64090  hydropower
# 3      angel_i_ii_iii -13.66330  -70.53820  hydropower
# 4           anto_ruiz -13.88330  -70.20000  hydropower
#
#                       geometry
# 0   POINT (-78.19793 -2.25617)
# 1    POINT (-55.00000 5.00000)
# 2  POINT (-65.64090 -17.00910)
# 3  POINT (-70.53820 -13.66330)
# 4  POINT (-70.20000 -13.88330)

# %% [markdown]
# ## IV. Save data as .CSV

# %%
save_df_as_csv(df, "../data/all_projects.csv")
save_df_as_csv(geo_coords, "../data/project_coords.csv")

# %% [markdown]
# ## V. Initial data exploration
#
# Very quickly just see the data to see if there's anything that sticks out to us

# %% [markdown]
# ### a. Country summary

# %%
# Check number of projects by country
fig = px.bar(df, x='country', color='sector_type')
fig.update_layout(
    title='Projects by sector per country', 
    xaxis = dict(
        title='Country'
    ), 
    yaxis = dict(
        title='Project count'
    ), 
    barmode='group', 
    paper_bgcolor='#FFFFFF', 
    showlegend=True,
    width=800,
    height=500
)
